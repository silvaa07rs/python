# %% [markdown]
# <a href="https://colab.research.google.com/github/silvaa07rs/python/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA1💙 ⚽ 💯**
#
# ![image.png](data:image/png;base64,...)

# %%
ano = "II"
print(ano," competição de programação dá Start")
# Out:
# II  competição de programação dá Start

# %% [markdown]
# #**AULA** **2** 🐇 ⏰ 💯

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5* + livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais da ana são {pontos_ana}")
print(f" pontos totais de ana e rodrigo são{ pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais da ana são 46
#  pontos totais de ana e rodrigo são70

# %% [markdown]
# # **AULA** **3** 💣 🎱 💯

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo
print(f"João recebeu {figurinhas_joao} figurinhas")
# Out:
# Digite o total de figurinhas: 2
# Digite o número de amigos: 2
# João recebeu 0 figurinhas

# %% [markdown]
# # **AULA 4** ⏰ ▶ ⚓

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# # **AULA 5** ⛽ ⛔ ✅

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} / {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 5
# 5 / 1 = 5
# 5 / 2 = 2
# 5 / 3 = 1
# 5 / 4 = 1
# 5 / 5 = 1
# 5 / 6 = 0
# 5 / 7 = 0
# 5 / 8 = 0
# 5 / 9 = 0
# 5 / 10 = 0

# %% [markdown]
# # **AULA 6** chatbot **☕** ☣ ✳

# %%
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
print(f"Ótimo, {nome},vamos falar sobre Python!")
elif resposta == "javascript":
print(f"ótimo,{nome},vamos falar sobre Javascript")
elif resposta == "javascript":
print(f"Otimo, {nome}, vamos falar sobre matemática!")
else:
print(f" Que pena, {nome}, não sei falar dess assunto")

# %% [markdown]
# # **AULA 7-listas** ⛅ ⏰ 〽

# %%
import random
dica = [
"🌅 Todo dia é uma nova chance pra recomeçar",

"💪 Acredite no seu potencial — você é mais forte do que imagina",

"🌻 Mesmo em dias nublados, o sol continua brilhando lá em cima",

"🚀 Sonhar grande dá o mesmo trabalho que sonhar pequeno. Vai com tudo",

"🔥 Transforme seus medos em combustível pra vencer",

"🌈 Depois da tempestade, vem o arco-íris — sempre,"

"⭐ Você não precisa ser perfeito, só precisa continuar tentando."
]
while True:
  pedido = input("digite 'dica' para receber uma dica ou 'sair' para encerrar \n").lower

  if pedido == "dica":
    dica = random.choice(dica) #escolher uma dica aleatoria sair
    print(f"dica {dica} \n)"
    break
  else:
    print("comando invalio. \n")
    break
